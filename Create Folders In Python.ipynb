# %%
# import operating system module and pandas libraries to read excel values
import os
import numpy as np
import pandas as pd
import shutil
#Shutil Library Can move rename files or folders

# give path to the folder
#put r before the path it will convert your normal string to raw string
path=r"C:\Users\Admin\Desktop\Create Folders from Excel List using Python"
os.chdir(path)

#print excel
data=pd.read_excel(r"C:\Users\Admin\Desktop\Create Folders from Excel List using Python\Property images.xlsx")
result=data.values
# print(result)
#This will convert the excel column with name "Folder Name" into a list
folderlist= data['Folder name'].tolist()


#Now we will remove duplicates from our list and will just stick to unique Folder names
FolderNameList=np.unique(folderlist)

#Make Root Folder
Newfolder="Property Images Project"
os.makedirs(Newfolder)

#Set Directory path to Created Root Folder 
path=r"C:\Users\Admin\Desktop\Create Folders from Excel List using Python\Property Images Project"
os.chdir(path)

#For loop to Make New Folders from the values stored in list
for i in UniqueFolders:
#Use if not to check if the folder doesnt exist in the directory.If its not this will make the folder 
    if not os.path.exists(i):
#Make Directory
        os.makedirs(i)

#Set Directory path to a Folder where all images are present
path=r"C:\Users\Admin\Desktop\Create Folders from Excel List using Python\Property images"
os.chdir(path)

# Store all the Images name that are present in a directory in a list
ImagesList=os.listdir()

#Use for loop to check each image one by one in excel
for i in ImagesList:
#     replace the extension because in excel only file name is present 
    Imagename=i. replace(".JPG", "")
# Query to Check if image present in directory is also present in excel in column "SV Image 1"
    ImageCheck1=data[Imagename == data['SV Image 1']]
# Query to Check if image present in directory is also present in excel in column "SV Image 2"
    ImageCheck2=data[Imagename == data['SV Image 2']]
# Converting the Return Query Row into List
    QueryImage1=ImageCheck1['Folder name'].tolist()
# Converting the Return Query Row into List
    QueryImage2=ImageCheck2['Folder name'].tolist()
    
# Check all Image files in  Column SV Image 1  
# if the query is not empty run this code if its empty go down to the second if condition
    if not QueryImage1==[]:
        FolderNameImage1=QueryImage1[0]
#Setting Source Directory
        source = i
#Setting Destination Directory
        destination = "C:\\Users\\Admin\\Desktop\\Create Folders from Excel List using Python\\Property Images Project\\"+FolderNameImage1
#Using Shutil to move the image from source to our desired destination
        shutil.move(source, destination)

# Check all Image files in  Column SV Image 2
# if the query is not empty run this code if its empty return to the loop
    if not QueryImage2==[]:
        FolderNameImage2=QueryImage2[0]
#Setting Source Directory
        source = i
#Setting Destination Directory
        destination = "C:\\Users\\Admin\\Desktop\\Create Folders from Excel List using Python\\Property Images Project\\"+FolderNameImage2
#Using Shutil to move the image from source to our desired destination
        shutil.move(source, destination)
